-- %%
ALTER TABLE catalog_name.on_boarding.wikipedia_articles
SET TBLPROPERTIES (
  delta.timeUntilArchived = '3 Days'
)

-- %%
select * from catalog_name.on_boarding.wikipedia_articles

-- %%
select *
FROM catalog_name.on_boarding.wikipedia_articles 
WHERE id >= 39188168
LIMIT 10001

-- %%
ALTER TABLE catalog_name.on_boarding.wikipedia_articles
SET TBLPROPERTIES (
  delta.timeUntilArchived = '3000 Days'
)

-- %%
-- insert into catalog_name.on_boarding.wikipedia_articles 
-- select * from catalog_name.on_boarding.wikipedia_articles 
-- where id=39188168

-- %%
SET use_cached_result = false;

-- %%
--SELECT distinct _metadata.file_name, _metadata.file_modification_time  AS file_modification_time, title, id
select *
FROM catalog_name.on_boarding.wikipedia_articles 
WHERE id >= 39188168
LIMIT 10001

-- %%
SHOW ARCHIVED FILES FOR catalog_name.on_boarding.wikipedia_articles WHERE id >= 39188168
